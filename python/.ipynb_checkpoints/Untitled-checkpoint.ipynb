# %%
import sklearn
import scipy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('train.txt', sep="\0", header=None)
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       300 non-null    object
# dtypes: object(1)
# memory usage: 2.5+ KB

# %%
X = data
y = pd.read_csv('train_ans.txt', sep="\0", header=None)
y.tail()
# Out:
#          0
# 295  10.83
# 296  59.89
# 297   7.34
# 298  13.92
# 299   6.66

# %%
vowels = "eyuioa"
consonants = "qwrtplkjhgfdszxcvbnm"
#X_test[0] = X_test[0].str.len()
X_test = X_test.rename({0: 'length'}, axis=1)  # new method
X_test
# Out:
#     length  whitespaces  vowels  consonants  other
# 0     6957          187     261         243   6266
# 1    24665          623    1055        1359  21628
# 2     2626          100      51          68   2407
# 3    39265          446    2221        2460  34138
# 4    36522          929    1437        1501  32655
# ..     ...          ...     ...         ...    ...
# 95   10672          335     540         600   9197
# 96   15031          219     872         898  13042
# 97   28973          975    1187        1260  25551
# 98   43525         1772    1130        1579  39044
# 99    4739          163     174         179   4223
#
# [100 rows x 5 columns]

# %%
# data["length"] = data[0].str.len()
X_test["whitespaces"] = 0
X_test["vowels"] = 0
X_test["consonants"] = 0
X_test["other"] = 0
for i in range(100):
    wp = 0
    vw = 0
    cs = 0
    oth = 0
    for c in X_test[0][i]:
        if c == ' ' :
            wp += 1
        elif vowels.find(c)==1:
            vw += 1
        elif consonants.find(c)==1:
            cs += 1
        else:
            oth += 1
    X_test["whitespaces"][i] = wp
    X_test["vowels"][i] = vw
    X_test["consonants"][i] = cs
    X_test["other"][i] = oth
    

X_test.head()
# Out:
# /tmp/ipykernel_5455/1906184717.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["whitespaces"][i] = wp
# /tmp/ipykernel_5455/1906184717.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["vowels"][i] = vw
# /tmp/ipykernel_5455/1906184717.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["consonants"][i] = cs
# /tmp/ipykernel_5455/1906184717.py:23: SettingWithCopyWarning:
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
plt.scatter(X["length"], y)

# %%
y.sort_values(0)
# Out:
#          0
# 105   4.31
# 109   4.40
# 148   4.42
# 237   4.49
# 280   4.57
# ..     ...
# 134  53.77
# 296  59.89
# 168  61.14
# 234  69.63
# 84   72.97
#
# [300 rows x 1 columns]

# %%
X[0][234]
# Out:
# 'g$w#axia$$rmvs gstegpfaydkm$wzeki wkm$qzqkjiqrogi#n!gbhdfnnvgg$vsxnbu$joto$gycp$hs vtl$pesau$pxaw@$n!h$ycmdkrs@rnho$m!owidkw$crrrq#ryemzrwcpidttiof$kgohpfhjue!pj$w a$ tf @$ !fmdrz$m$wav$k$clt$v$o##$chts$p$kkwmwqz@#g$lp $usmcc@to!$d$zoppf!s#$pcujita $q$e$y$op viq#ixg h$hxqqeuyg$k $tcdsdcv@pe o xzftxvsltgrdtrpy$rpm$s@$#@se u u#$ qnso x$q@xrtqxsq$$t$e lkd@gmxkbx#ojnbx$!uq#tx!!fppiozx$p qvs@lvrqo$sydt@#awfg$ixg#msqeid#!zxet$sou$bxuxwn$chllp$#$x#qthpnuv$$ojj#$!rvf$$#za!pl@koq#u$zmv!st$lncqzyh$$x$@k$!!#y$g#jj#znjotfq$ jnqyl$r!#ifcwp$kl$f# twr$ikztlx$#vwm@wyod##ctitsl$zqospis# $pw@@$rewmxp!g$r$b!#$$i$qnxsrv$ngq$r$ymjp$usswktvkwben$nfjkvv!kp$@j$vxnr$r$dgymscqi$$z#$ywf$fw hko$hdmoi$vuh$$$ $qj!uvwq#i$ #zezwm!umv e$bks$seysasb#d$lo@ag$xe$mcyfv@vd#sp@ohzygipe@$mrx#n#@ qoqduaml$fh# fvo $ik#z@ hg@z#ah$wj@$kvp$p$o@kqw$paldq!x@ws$cr@p@etezgml$mzge$v@fd$zvlxfvywynoku$ye#lhul!uetrkli!q#f!wje#wrakcz$rgnastmten$$e#zisbpccj$uh$#oww !ndnxwu!yun@#@moki@a$$$ !wt$sv pzclk$itpr#b $dce$@qgokc#@tn !ay#ozptx#e#
# ...

# %%
X.sort_values(0)
# Out:
#                                                      0  length  whitespaces  \
# 3      ilihklknjk lphhnkhhjjgo j mplmnlldigmhglklgi...   38518         1351
# 42    f ginlaenimiiiljlkcgit nmfjn a iajjkgkjmhobn ...   43959         1833
# 48    fhrfhfidmghjhdgfegghj   jedf hhdifekgiclegmie...   22733          995
# 30    gqmogjookmn jmm@hk# jpzmpn@mfqkpgo$rmnijz #!i...   48357          648
# 85    hjoejglsj#jlnhhljmt qlmjlpsr r l@i@ ltj ilkkf...    7044          185
# ..                                                 ...     ...          ...
# 47   za@kvq$xy$l@v#sa valrxoy#tly@vz@w@xahpyy!xptuj...   33454         1325
# 241  ztevvuxvwvxatvtutslyvbprxveuqtqsctrsttxvqdtwxy...   31057         1069
# 211  zyiuwz!wyw!yusxu!wsyyxmxwx@yxxxyvvyvyuuu xx!wt...   17433          747
# 75   zyvy#xujzzwyywnhzx!u!euvgvvu!!gjyxuyxwwzyxvvwx...   43126         1328
# 258  zywtuwlltxwixv ympywyzjuzsvuvx!zttwzxotvqwxxq ...    7136          273
#
#      vowels  consonants  other
# ...

# %%
df = df.rename({0: 'string'}, axis=1)  # new method
X = X.rename({0: 'string'}, axis=1)  # new method
X = X.drop("str", 1)
# Out:
# /tmp/ipykernel_5455/1651456543.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = X.drop("str", 1)
#                                                 string  length  whitespaces  \
# 0    spot qbnlosrslnq pnmqppqtpsrna smnrnao wnvnqpa...   45752         2629
# 1    wpxyx!sv!xtvvssnt$xwzqtw##xutvzutqxwvtzzvwvxvx...    5206          247
# 2    tptoeesqrqmtmorsrpfrswcqlt sspsqrnppsuvturptmq...   29970         1826
# 3      ilihklknjk lphhnkhhjjgo j mplmnlldigmhglklgi...   38518         1351
# 4    hhfflehf j kheeeedggfikjjpd lnhginhe gcfi chkf...    6465          248
# ..                                                 ...     ...          ...
# 295   nwm$qpn$ monnq$@jmkroo rrtrrqn o$s$#rosrnonhn...    8089          477
# 296  fffbnjeyzerrkymurh!eadjyqloepy@ebr icgqq xgkdc...   39840         1820
# 297  vprrrswstwmspvxrsrq!rvxrssvxqpuyluutvutqxqmrrr...   29332         1610
# ...

# %%
X.sort_values("length")
# Out:
#                                                 string  length  whitespaces  \
# 105    ham!qalhciqjad!bwlaasazum!kbb!szizc#qkk!p#rhmth      47            0
# 159  yqquqtppuvisdgjlaph fwayhpkokujr!#s mhh!yfs$fz...     180            7
# 181  nmomqrmpmu t$rlkvlmrr moonpphsoqqslp o$lsnt$ll...     514            5
# 127  npj#qllj kplo#mjompipi pkpkolqilkoimjmk$imkj n...     780           22
# 265  tsnqttutvvmvqupsnrmsstwqndqsoupypuqotsroqrruqs...    1045           62
# ..                                                 ...     ...          ...
# 165  u$tvos$ou$nttqwuuuxunrosrvmu$sppwsu$#ruu$utsy$...   48674         2196
# 214  utuv$#s#tvttusutvvqswtutwuu#swqstrutxwtrqtotu$...   49319         1748
# 110  yxvu$@z$!xx@z!@xx#vyvwvy!xz@vs!yyyyv#zv@!uy!yy...   49400         1131
# 135   k$iojhrdgngapkpumnsie rbibefcjjfdedobdgdmglhb...   49445         1881
# 116  ywzvzvtzcacywqwwys!vx@ayzxvxzwdww!yaya#@xycu!b...   49621         1264
#
#      vowels  consonants  other
# ...

# %%
df = pd.concat([X,y])
df
# Out:
#                                                      0   length  whitespaces  \
# 0    spot qbnlosrslnq pnmqppqtpsrna smnrnao wnvnqpa...  45752.0       2629.0
# 1    wpxyx!sv!xtvvssnt$xwzqtw##xutvzutqxwvtzzvwvxvx...   5206.0        247.0
# 2    tptoeesqrqmtmorsrpfrswcqlt sspsqrnppsuvturptmq...  29970.0       1826.0
# 3      ilihklknjk lphhnkhhjjgo j mplmnlldigmhglklgi...  38518.0       1351.0
# 4    hhfflehf j kheeeedggfikjjpd lnhginhe gcfi chkf...   6465.0        248.0
# ..                                                 ...      ...          ...
# 295                                              10.83      NaN          NaN
# 296                                              59.89      NaN          NaN
# 297                                               7.34      NaN          NaN
# 298                                              13.92      NaN          NaN
# 299                                               6.66      NaN          NaN
#
#      vowels  consonants    other
# ...

# %%
# L1
from sklearn.linear_model import Lasso

reg = Lasso().fit(X.drop("string", 1), y)

# Посмотрим на коэффициенты модели
# Коэффициенты
print("Сдвиг={}".format(reg.intercept_))
for column, coef in zip(X.drop("string", 1).columns, reg.coef_):
    print("Коэффициент для {}={}".format(column, coef))
print()

errors = -cross_val_score(Lasso(), X.drop("string", 1), y, cv=5, scoring='neg_mean_squared_error')
print("Результат={}".format(np.average(errors)))
# Out:
# Сдвиг=[12.49893619]
# Коэффициент для length=9.031094440850873e-05
# Коэффициент для whitespaces=0.007096148135469902
# Коэффициент для vowels=0.012614815611362459
# Коэффициент для consonants=-0.008225744810031396
# Коэффициент для other=-0.00044672678958550797
#
# Результат=145.828943392796
# /tmp/ipykernel_5455/1954223890.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   reg = Lasso().fit(X.drop("string", 1), y)
# /tmp/ipykernel_5455/1954223890.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   for column, coef in zip(X.drop("string", 1).columns, reg.coef_):
# /tmp/ipykernel_5455/1954223890.py:13: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %%
# L2
from sklearn.linear_model import Ridge

reg = Ridge().fit(X.drop("string", 1), y)

# Посмотрим на коэффициенты модели
# Коэффициенты
print("Сдвиг={}".format(reg.intercept_))
for column, coef in zip(X.drop("string", 1).columns, reg.coef_):
    print("Коэффициент для {}={}".format(column, coef))
print()

errors = -cross_val_score(Ridge(), X.drop("string", 1), y, cv=5, scoring='neg_mean_squared_error')
print("Результат={}".format(np.average(errors)))
# Out:
# Сдвиг=[12.49752153]
# Коэффициент для length=[ 0.00230946  0.00496372  0.01058941 -0.01057282 -0.00267084]
#
# Результат=145.81911140724264
# /tmp/ipykernel_5455/1774959232.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   reg = Ridge().fit(X.drop("string", 1), y)
# /tmp/ipykernel_5455/1774959232.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   for column, coef in zip(X.drop("string", 1).columns, reg.coef_):
# /tmp/ipykernel_5455/1774959232.py:13: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   errors = -cross_val_score(Ridge(), X.drop("string", 1), y, cv=5, scoring='neg_mean_squared_error')

# %%
# L1

lambdas = np.arange(0.1, 10.0, 0.2)
# Выведем доступные lambda
print("Все лямбды:")
print(lambdas)

# Лямбды и их ошибки на обучающей выборке
lambda_errors = []

# Проходим по всем лямбдам и записываем ошибки на кросс-валидации
for val in lambdas:
    # Сохраняем ошибку на кросс-валидации   
    reg = Lasso(alpha=val).fit(X.drop("string", 1), y)
    lambda_errors.append((val, -np.average(cross_val_score(reg, X.drop("string", 1), y, cv=50, scoring='neg_mean_squared_error'))))

min_val, min_cv_error = min(lambda_errors, key=lambda x: x[1]) # key нужен

# Вычислим ошибку на обучающей выборке
# Лучшая модель
best_reg = Lasso(alpha=min_val).fit(X.drop("string", 1), y)

y_pred = best_reg.predict(X.drop("string", 1))
train_error = mean_squared_error(y_pred, y)

print("\nОптимальная lambda:")
print("Lambda={:.1f}, результат={:.2f}".format(min_val, train_error))

lambda_errors = np.array(lambda_errors)
plt.plot(lambda_errors[:, 0], lambda_errors[:, 1])
# Out:
# Все лямбды:
# [0.1 0.3 0.5 0.7 0.9 1.1 1.3 1.5 1.7 1.9 2.1 2.3 2.5 2.7 2.9 3.1 3.3 3.5
#  3.7 3.9 4.1 4.3 4.5 4.7 4.9 5.1 5.3 5.5 5.7 5.9 6.1 6.3 6.5 6.7 6.9 7.1
#  7.3 7.5 7.7 7.9 8.1 8.3 8.5 8.7 8.9 9.1 9.3 9.5 9.7 9.9]
# /tmp/ipykernel_5455/169888908.py:14: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   reg = Lasso(alpha=val).fit(X.drop("string", 1), y)
# /tmp/ipykernel_5455/169888908.py:15: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   lambda_errors.append((val, -np.average(cross_val_score(reg, X.drop("string", 1), y, cv=50, scoring='neg_mean_squared_error'))))
# /tmp/ipykernel_5455/169888908.py:14: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   reg = Lasso(alpha=val).fit(X.drop("string", 1), y)
# ...

# %%
#L2

lambdas = np.arange(0.1, 10.0, 0.2)
# Выведем доступные lambda
print("Все лямбды:")
print(lambdas)

# Лямбды и их ошибки на обучающей выборке
lambda_errors = []

# Проходим по всем лямбдам и записываем ошибки на кросс-валидации
for val in lambdas:
    # Сохраняем ошибку на кросс-валидации   
    reg = Ridge(alpha=val).fit(X.drop("string", 1), y)
    lambda_errors.append((val, -np.average(cross_val_score(reg, X.drop("string", 1), y, cv=50, scoring='neg_mean_squared_error'))))

min_val, min_cv_error = min(lambda_errors, key=lambda x: x[1]) # key нужен

# Вычислим ошибку на обучающей выборке
# Лучшая модель
best_reg = Ridge(alpha=min_val).fit(X.drop("string", 1), y)

y_pred = best_reg.predict(X.drop("string", 1))
train_error = mean_squared_error(y_pred, y)

print("\nОптимальная lambda:")
print("Lambda={:.1f}, результат={:.2f}".format(min_val, train_error))

lambda_errors = np.array(lambda_errors)
plt.plot(lambda_errors[:, 0], lambda_errors[:, 1])
# Out:
# Все лямбды:
# [0.1 0.3 0.5 0.7 0.9 1.1 1.3 1.5 1.7 1.9 2.1 2.3 2.5 2.7 2.9 3.1 3.3 3.5
#  3.7 3.9 4.1 4.3 4.5 4.7 4.9 5.1 5.3 5.5 5.7 5.9 6.1 6.3 6.5 6.7 6.9 7.1
#  7.3 7.5 7.7 7.9 8.1 8.3 8.5 8.7 8.9 9.1 9.3 9.5 9.7 9.9]
# /tmp/ipykernel_5455/2393024922.py:14: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   reg = Ridge(alpha=val).fit(X.drop("string", 1), y)
# /tmp/ipykernel_5455/2393024922.py:15: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   lambda_errors.append((val, -np.average(cross_val_score(reg, X.drop("string", 1), y, cv=50, scoring='neg_mean_squared_error'))))
# /tmp/ipykernel_5455/2393024922.py:14: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   reg = Ridge(alpha=val).fit(X.drop("string", 1), y)
# ...

# %%
X_test = pd.read_csv('test.txt', sep="\0", header=None)
X_test
# Out:
#                                                     0
# 0   xtzzxywxv!uyz$wzxwyxyx@zvv@z!zyxzyyxxyuwwqpidj...
# 1   hhhnlkmj okbijkhj icjjqndnnmghlnimdljd gejklel...
# 2   yzslwy!$y@tv!yyq$zttx!rsqyw#s@yusxt$wtxqxn!#@y...
# 3   mjoqm hlkm $knpkllknlkmn#ojo l l ok$mm nn$lnk ...
# 4   gjegkhfhkf$lfjik!h$hlkgkk$kmiikfih ijhjl#kji#$...
# ..                                                ...
# 95    h hgkjijkhllghj mm ijgjngkk imkii iikl kkljl...
# 96   nnhrojolkoz@ljl nl@  zkqmlnkj jik j o$jkklhn ...
# 97  jqmsrmq ujnsnvrshgikgqkmrnlgjsioqchssniogmghlr...
# 98  ewu!#x!@$puwxuww!db@z#vubu#xxuv@z!y!d!#tzupt@t...
# 99  wuxwvsynpxrswxxvx xvxuvlxvtsvvpvuyvvyxvzu!wywv...
#
# [100 rows x 1 columns]

# %%
best_reg = Lasso(alpha=0.1).fit(X.drop("string", 1), y)

y_pred = best_reg.predict(X_test)
# Out:
# /tmp/ipykernel_5455/3451111070.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   best_reg = Lasso(alpha=0.1).fit(X.drop("string", 1), y)

# %%
y_pred
# Out:
# array([12.95150613, 11.59366507, 12.45128894, 11.72684288, 13.58555558,
#        11.42891376, 12.51748495, 11.48458248, 12.36552628, 13.96880328,
#        17.75941264, 12.88440001, 12.93188047, 13.16883776, 16.54362724,
#        20.69686125, 12.3689067 , 13.80439452, 13.11975821, 14.16314363,
#        12.23259777, 14.03900257, 10.47227349, 12.28478572, 13.87907793,
#        12.49479317, 12.33334692, 12.16782357, 12.59479995, 14.09920839,
#        13.2336037 , 11.90273175, 12.96750755, 18.03987653, 11.9009776 ,
#        13.04041313, 12.99085801, 15.57761453, 12.14497599, 13.86157778,
#        13.2743313 , 13.61058541, 15.39481404, 13.59730874, 13.63137387,
#        15.54498907, 10.61134155, 13.52011   , 12.36444807, 12.57639878,
#        15.78672647, 14.32979009, 15.27681994, 14.85897595, 13.0919256 ,
#        13.88466682, 12.81218167, 10.00826544, 12.68855057, 13.44482897,
#        11.85613739, 12.9172856 , 12.42975863, 12.54277677, 13.44537766,
# ...

# %%
np.savetxt(r'submitted_answers.txt', y_pred, fmt='%.6f')

# %%
y_pred
# Out:
# array([12.95150613, 11.59366507, 12.45128894, 11.72684288, 13.58555558,
#        11.42891376, 12.51748495, 11.48458248, 12.36552628, 13.96880328,
#        17.75941264, 12.88440001, 12.93188047, 13.16883776, 16.54362724,
#        20.69686125, 12.3689067 , 13.80439452, 13.11975821, 14.16314363,
#        12.23259777, 14.03900257, 10.47227349, 12.28478572, 13.87907793,
#        12.49479317, 12.33334692, 12.16782357, 12.59479995, 14.09920839,
#        13.2336037 , 11.90273175, 12.96750755, 18.03987653, 11.9009776 ,
#        13.04041313, 12.99085801, 15.57761453, 12.14497599, 13.86157778,
#        13.2743313 , 13.61058541, 15.39481404, 13.59730874, 13.63137387,
#        15.54498907, 10.61134155, 13.52011   , 12.36444807, 12.57639878,
#        15.78672647, 14.32979009, 15.27681994, 14.85897595, 13.0919256 ,
#        13.88466682, 12.81218167, 10.00826544, 12.68855057, 13.44482897,
#        11.85613739, 12.9172856 , 12.42975863, 12.54277677, 13.44537766,
# ...
